# %% [markdown]
# <div align="center"> <h1>Country Other-Agricultural-Soil-Emissions Emissions CSV</h1></div>

# %% [markdown]
# ### About This Notebook
# This notebook explores the contents of the csv file.
# Various exploratory techniques will be used to analyze the content of the csv and perform any necessary cleanups.

# %%
# Import necessary libraries to use for the exploration & analysis
import csv 
import pandas as pd
import matplotlib.pyplot as plt

# Set up the number of columns to use when showing a data frame using pandas
pd.set_option('display.max_columns', 200)

# %%
# Import the csv file and convert it to a pandas data frame 
df = pd.read_csv("../data/agriculture/country_other-agricultural-soil-emissions_emissions.csv")

# %%
# Show the shape of the data frame (rows, columns)
# The returned value is the number of rows and columns in the dataframe
df.shape
# Out:
# (8785, 10)

# %%
# Show the first 5 rows by using the head command
df.head()
# Out:
#   iso3_country           start_time             end_time  \
# 0          SHN  2019-01-01 00:00:00  2019-12-31 00:00:00
# 1          SHN  2019-01-01 00:00:00  2019-12-31 00:00:00
# 2          SHN  2019-01-01 00:00:00  2019-12-31 00:00:00
# 3          SHN  2019-01-01 00:00:00  2019-12-31 00:00:00
# 4          SHN  2019-01-01 00:00:00  2019-12-31 00:00:00
#
#            original_inventory_sector         gas  emissions_quantity  \
# 0  other-agricultural-soil-emissions         co2                 0.0
# 1  other-agricultural-soil-emissions         n2o                 0.0
# 2  other-agricultural-soil-emissions         ch4                 0.0
# 3  other-agricultural-soil-emissions   co2e_20yr                 0.0
# 4  other-agricultural-soil-emissions  co2e_100yr                 0.0
#
#   emissions_quantity_units  temporal_granularity               created_date  \
# 0                   tonnes                   NaN  2022-09-06 12:39:52.76017
# 1                   tonnes                   NaN  2022-09-06 12:39:52.76017
# 2                   tonnes                   NaN  2022-09-06 12:39:52.76017
# 3                   tonnes                   NaN  2022-09-06 12:39:52.76017
# 4                   tonnes                   NaN  2022-09-06 12:39:52.76017
#
#   modified_date
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
# List out the columns 
columns = df.columns

index = 0 
print("Column Index\t Column Name")
for column in columns:
    print(f"{index}\t\t {column}")
    index += 1
# Out:
# Column Index	 Column Name
# 0		 iso3_country
# 1		 start_time
# 2		 end_time
# 3		 original_inventory_sector
# 4		 gas
# 5		 emissions_quantity
# 6		 emissions_quantity_units
# 7		 temporal_granularity
# 8		 created_date
# 9		 modified_date

# %%
# Check the data type of the column's content
df.dtypes
# Out:
# iso3_country                  object
# start_time                    object
# end_time                      object
# original_inventory_sector     object
# gas                           object
# emissions_quantity           float64
# emissions_quantity_units      object
# temporal_granularity         float64
# created_date                  object
# modified_date                 object
# dtype: object

# %% [markdown]
# #### Here are some of the keys for understanding pandas data types
#
# object => String
#
# float64 => Float

# %%
# Check on the overal distribution of all numerical data columns
df.describe()
# Out:
#        emissions_quantity  temporal_granularity
# count        7.357000e+03                   0.0
# mean         1.783291e+06                   NaN
# std          8.110952e+06                   NaN
# min          0.000000e+00                   NaN
# 25%          0.000000e+00                   NaN
# 50%          9.912000e+02                   NaN
# 75%          3.512784e+05                   NaN
# max          1.038448e+08                   NaN

# %%
# Check on the summarized technical information of the pandas dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8785 entries, 0 to 8784
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   iso3_country               8785 non-null   object
#  1   start_time                 8785 non-null   object
#  2   end_time                   8785 non-null   object
#  3   original_inventory_sector  8785 non-null   object
#  4   gas                        8785 non-null   object
#  5   emissions_quantity         7357 non-null   float64
#  6   emissions_quantity_units   8785 non-null   object
#  7   temporal_granularity       0 non-null      float64
#  8   created_date               8785 non-null   object
#  9   modified_date              1194 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 686.5+ KB

# %%
# Drop all columns with null values
# Assign the dataframe with the dropped column to a new variable to save changes.
df = df.drop(["temporal_granularity"], axis=1)

# %%
# Confirm columns or Series (as they are called in pandas) are dropped
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8785 entries, 0 to 8784
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   iso3_country               8785 non-null   object
#  1   start_time                 8785 non-null   object
#  2   end_time                   8785 non-null   object
#  3   original_inventory_sector  8785 non-null   object
#  4   gas                        8785 non-null   object
#  5   emissions_quantity         7357 non-null   float64
#  6   emissions_quantity_units   8785 non-null   object
#  7   created_date               8785 non-null   object
#  8   modified_date              1194 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 617.8+ KB

# %%
# Display the top [insert number here] rows to have a glimpse of how the dataframe looks like
# The number passed to the `df.head()` is the number of rows that will be returned
df.head(10)
# Out:
#   iso3_country           start_time             end_time  \
# 0          SHN  2019-01-01 00:00:00  2019-12-31 00:00:00
# 1          SHN  2019-01-01 00:00:00  2019-12-31 00:00:00
# 2          SHN  2019-01-01 00:00:00  2019-12-31 00:00:00
# 3          SHN  2019-01-01 00:00:00  2019-12-31 00:00:00
# 4          SHN  2019-01-01 00:00:00  2019-12-31 00:00:00
# 5          SLB  2019-01-01 00:00:00  2019-12-31 00:00:00
# 6          SLB  2019-01-01 00:00:00  2019-12-31 00:00:00
# 7          SLB  2019-01-01 00:00:00  2019-12-31 00:00:00
# 8          SLB  2019-01-01 00:00:00  2019-12-31 00:00:00
# 9          SLB  2019-01-01 00:00:00  2019-12-31 00:00:00
#
#            original_inventory_sector         gas  emissions_quantity  \
# 0  other-agricultural-soil-emissions         co2                 0.0
# 1  other-agricultural-soil-emissions         n2o                 0.0
# 2  other-agricultural-soil-emissions         ch4                 0.0
# 3  other-agricultural-soil-emissions   co2e_20yr                 0.0
# 4  other-agricultural-soil-emissions  co2e_100yr                 0.0
# 5  other-agricultural-soil-emissions         co2                 0.0
# 6  other-agricultural-soil-emissions         n2o                34.5
# 7  other-agricultural-soil-emissions         ch4                 0.0
# 8  other-agricultural-soil-emissions   co2e_20yr              9108.0
# 9  other-agricultural-soil-emissions  co2e_100yr              9142.5
#
#   emissions_quantity_units               created_date modified_date
# 0                   tonnes  2022-09-06 12:39:52.76017           NaN
# 1                   tonnes  2022-09-06 12:39:52.76017           NaN
# 2                   tonnes  2022-09-06 12:39:52.76017           NaN
# 3                   tonnes  2022-09-06 12:39:52.76017           NaN
# 4                   tonnes  2022-09-06 12:39:52.76017           NaN
# 5                   tonnes  2022-09-06 12:39:52.76017           NaN
# 6                   tonnes  2022-09-06 12:39:52.76017           NaN
# 7                   tonnes  2022-09-06 12:39:52.76017           NaN
# 8                   tonnes  2022-09-06 12:39:52.76017           NaN
# 9                   tonnes  2022-09-06 12:39:52.76017           NaN

# %%
# Display the bottom [insert number here] rows to have a glimpse of how the dataframe looks like
# The number passed to the `df.tail()` is the number of rows that will be returned
df.tail(10)
# Out:
#      iso3_country           start_time             end_time  \
# 8775          TUV  2021-01-01 00:00:00  2021-12-31 00:00:00
# 8776          UMI  2021-01-01 00:00:00  2021-12-31 00:00:00
# 8777          UMI  2021-01-01 00:00:00  2021-12-31 00:00:00
# 8778          VAT  2021-01-01 00:00:00  2021-12-31 00:00:00
# 8779          VAT  2021-01-01 00:00:00  2021-12-31 00:00:00
# 8780          WLF  2021-01-01 00:00:00  2021-12-31 00:00:00
# 8781          WLF  2021-01-01 00:00:00  2021-12-31 00:00:00
# 8782          WLF  2021-01-01 00:00:00  2021-12-31 00:00:00
# 8783          WLF  2021-01-01 00:00:00  2021-12-31 00:00:00
# 8784          WLF  2021-01-01 00:00:00  2021-12-31 00:00:00
#
#               original_inventory_sector         gas  emissions_quantity  \
# 8775  other-agricultural-soil-emissions  co2e_100yr                 NaN
# 8776  other-agricultural-soil-emissions   co2e_20yr                 NaN
# 8777  other-agricultural-soil-emissions  co2e_100yr                 NaN
# 8778  other-agricultural-soil-emissions   co2e_20yr                 NaN
# 8779  other-agricultural-soil-emissions  co2e_100yr                 NaN
# 8780  other-agricultural-soil-emissions         co2                 NaN
# 8781  other-agricultural-soil-emissions         n2o                 NaN
# 8782  other-agricultural-soil-emissions         ch4                 NaN
# 8783  other-agricultural-soil-emissions   co2e_20yr                 NaN
# 8784  other-agricultural-soil-emissions  co2e_100yr                 NaN
#
#      emissions_quantity_units               created_date modified_date
# 8775                   tonnes  2022-09-07 09:56:37.90632           NaN
# 8776                   tonnes  2022-09-07 09:56:37.90632           NaN
# 8777                   tonnes  2022-09-07 09:56:37.90632           NaN
# 8778                   tonnes  2022-09-07 09:56:37.90632           NaN
# 8779                   tonnes  2022-09-07 09:56:37.90632           NaN
# 8780                   tonnes  2022-09-07 09:56:37.90632           NaN
# 8781                   tonnes  2022-09-07 09:56:37.90632           NaN
# 8782                   tonnes  2022-09-07 09:56:37.90632           NaN
# 8783                   tonnes  2022-09-07 09:56:37.90632           NaN
# 8784                   tonnes  2022-09-07 09:56:37.90632           NaN
