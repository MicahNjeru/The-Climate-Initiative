# %% [markdown]
# <div align="center"> <h1>Asset Manure-Management Emissions CSV</h1></div>

# %% [markdown]
# ### About This Notebook
# This notebook explores the contents of the csv file.
# Various exploratory techniques will be used to analyze the content of the csv and perform any necessary cleanups.

# %%
# Import necessary libraries to use for the exploration & analysis
import csv 
import pandas as pd
import matplotlib.pyplot as plt

# Set up the number of columns to use when showing a data frame using pandas
pd.set_option('display.max_columns', 200)

# %%
# Import the csv file and convert it to a pandas data frame 
df = pd.read_csv("../data/agriculture/asset_manure-management_emissions.csv")

# %%
# Show the shape of the data frame (rows, columns)
# The returned value is the number of rows and columns in the dataframe
df.shape
# Out:
# (15245, 21)

# %%
# Show the first 5 rows by using the head command
df.head()
# Out:
#    asset_id iso3_country original_inventory_sector           start_time  \
# 0   5096624          USA         manure-management  2020-01-01 00:00:00
# 1   5096624          USA         manure-management  2020-01-01 00:00:00
# 2   5096624          USA         manure-management  2020-01-01 00:00:00
# 3   5096624          USA         manure-management  2020-01-01 00:00:00
# 4   5096624          USA         manure-management  2020-01-01 00:00:00
#
#               end_time temporal_granularity  lat_lon         gas  \
# 0  2020-12-31 00:00:00               annual      NaN         co2
# 1  2020-12-31 00:00:00               annual      NaN         ch4
# 2  2020-12-31 00:00:00               annual      NaN         n2o
# 3  2020-12-31 00:00:00               annual      NaN  co2e_100yr
# 4  2020-12-31 00:00:00               annual      NaN   co2e_20yr
#
#    emissions_quantity  emissions_factor      emissions_factor_units  capacity  \
# 0            0.000000          0.000000  tonnes_gas_per_animal_head  0.001023
# 1            3.308000          0.002000  tonnes_gas_per_animal_head  0.001023
# 2           16.375634          0.009901  tonnes_gas_per_animal_head  0.001023
# 3         4415.791310          0.009901  tonnes_gas_per_animal_head  0.001023
# 4         4617.414944          0.009901  tonnes_gas_per_animal_head  0.001023
#
#                      capacity_units  capacity_factor  activity  \
# 0  area_sq_meters_of_intensive_farm              NaN      1654
# 1  area_sq_meters_of_intensive_farm              NaN      1654
# 2  area_sq_meters_of_intensive_farm              NaN      1654
# 3  area_sq_meters_of_intensive_farm              NaN      1654
# 4  area_sq_meters_of_intensive_farm              NaN      1654
#
#             activity_units                created_date  \
# 0  total_animal_head_count  2022-09-13 19:15:27.534582
# 1  total_animal_head_count  2022-09-13 19:15:27.534582
# 2  total_animal_head_count  2022-09-13 19:15:27.534582
# 3  total_animal_head_count  2022-09-13 19:15:27.534582
# 4  total_animal_head_count  2022-09-13 19:15:27.534582
#
#                 modified_date       asset_name              asset_type  \
# 0  2022-10-14 21:11:31.952288  USA_CA_beef_100  manure_management_beef
# 1  2022-10-14 21:11:31.952288  USA_CA_beef_100  manure_management_beef
# 2  2022-10-14 21:11:31.952288  USA_CA_beef_100  manure_management_beef
# 3  2022-10-14 21:11:31.952288  USA_CA_beef_100  manure_management_beef
# 4  2022-10-14 21:11:31.952288  USA_CA_beef_100  manure_management_beef
#
#                           st_astext
# 0  POINT(-121.14280701 37.69197101)
# 1  POINT(-121.14280701 37.69197101)
# 2  POINT(-121.14280701 37.69197101)
# 3  POINT(-121.14280701 37.69197101)
# 4  POINT(-121.14280701 37.69197101)

# %%
# List out the columns 
columns = df.columns

index = 0 
print("Column Index\t Column Name")
for column in columns:
    print(f"{index}\t\t {column}")
    index += 1
# Out:
# Column Index	 Column Name
# 0		 asset_id
# 1		 iso3_country
# 2		 original_inventory_sector
# 3		 start_time
# 4		 end_time
# 5		 temporal_granularity
# 6		 lat_lon
# 7		 gas
# 8		 emissions_quantity
# 9		 emissions_factor
# 10		 emissions_factor_units
# 11		 capacity
# 12		 capacity_units
# 13		 capacity_factor
# 14		 activity
# 15		 activity_units
# 16		 created_date
# 17		 modified_date
# 18		 asset_name
# 19		 asset_type
# 20		 st_astext

# %%
# Check the data type of the column's content
df.dtypes
# Out:
# asset_id                       int64
# iso3_country                  object
# original_inventory_sector     object
# start_time                    object
# end_time                      object
# temporal_granularity          object
# lat_lon                      float64
# gas                           object
# emissions_quantity           float64
# emissions_factor             float64
# emissions_factor_units        object
# capacity                     float64
# capacity_units                object
# capacity_factor              float64
# activity                       int64
# activity_units                object
# created_date                  object
# modified_date                 object
# asset_name                    object
# asset_type                    object
# st_astext                     object
# dtype: object

# %% [markdown]
# #### Here are some of the keys for understanding pandas data types
# int64 => Integer
#
# object => String
#
# float64 => Float

# %%
# Check on the overal distribution of all numerical data columns
df.describe()
# Out:
#            asset_id  lat_lon  emissions_quantity  emissions_factor  \
# count  1.524500e+04      0.0        15245.000000      15245.000000
# mean   1.830905e+07      NaN         7626.359461          0.014695
# std    1.549737e+08      NaN        26798.956391          0.019653
# min    5.096622e+06      NaN            0.000000          0.000000
# 25%    5.097043e+06      NaN            4.532000          0.002000
# 50%    5.097501e+06      NaN           59.285000          0.009901
# 75%    5.098268e+06      NaN         5704.715240          0.015458
# max    1.836078e+09      NaN       851531.000000          0.128000
#
#            capacity  capacity_factor       activity
# count  15245.000000              0.0   15245.000000
# mean       0.322632              NaN    5486.555592
# std        0.544975              NaN   13196.685771
# min        0.000006              NaN     100.000000
# 25%        0.002122              NaN     784.000000
# 50%        0.020440              NaN    1593.000000
# 75%        0.915607              NaN    3582.000000
# max        4.694419              NaN  188000.000000

# %%
# Check on the summarized technical information of the pandas dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15245 entries, 0 to 15244
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   asset_id                   15245 non-null  int64
#  1   iso3_country               15245 non-null  object
#  2   original_inventory_sector  15245 non-null  object
#  3   start_time                 15245 non-null  object
#  4   end_time                   15245 non-null  object
#  5   temporal_granularity       15245 non-null  object
#  6   lat_lon                    0 non-null      float64
#  7   gas                        15245 non-null  object
#  8   emissions_quantity         15245 non-null  float64
#  9   emissions_factor           15245 non-null  float64
#  10  emissions_factor_units     15135 non-null  object
#  11  capacity                   15245 non-null  float64
#  12  capacity_units             15135 non-null  object
#  13  capacity_factor            0 non-null      float64
#  14  activity                   15245 non-null  int64
#  15  activity_units             15135 non-null  object
#  16  created_date               15245 non-null  object
#  17  modified_date              15135 non-null  object
#  18  asset_name                 15245 non-null  object
#  19  asset_type                 15245 non-null  object
#  20  st_astext                  15245 non-null  object
# dtypes: float64(5), int64(2), object(14)
# memory usage: 2.4+ MB

# %%
# Drop all columns with null values
# Assign the dataframe with the dropped column to a new variable to save changes.
df = df.drop(["lat_lon", "capacity_factor"], axis=1)

# %%
# Confirm columns or Series (as they are called in pandas) are dropped
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15245 entries, 0 to 15244
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   asset_id                   15245 non-null  int64
#  1   iso3_country               15245 non-null  object
#  2   original_inventory_sector  15245 non-null  object
#  3   start_time                 15245 non-null  object
#  4   end_time                   15245 non-null  object
#  5   temporal_granularity       15245 non-null  object
#  6   gas                        15245 non-null  object
#  7   emissions_quantity         15245 non-null  float64
#  8   emissions_factor           15245 non-null  float64
#  9   emissions_factor_units     15135 non-null  object
#  10  capacity                   15245 non-null  float64
#  11  capacity_units             15135 non-null  object
#  12  activity                   15245 non-null  int64
#  13  activity_units             15135 non-null  object
#  14  created_date               15245 non-null  object
#  15  modified_date              15135 non-null  object
#  16  asset_name                 15245 non-null  object
#  17  asset_type                 15245 non-null  object
#  18  st_astext                  15245 non-null  object
# dtypes: float64(3), int64(2), object(14)
# memory usage: 2.2+ MB

# %%
# Display the top [insert number here] rows to have a glimpse of how the dataframe looks like
# The number passed to the `df.head()` is the number of rows that will be returned
df.head(10)
# Out:
#    asset_id iso3_country original_inventory_sector           start_time  \
# 0   5096624          USA         manure-management  2020-01-01 00:00:00
# 1   5096624          USA         manure-management  2020-01-01 00:00:00
# 2   5096624          USA         manure-management  2020-01-01 00:00:00
# 3   5096624          USA         manure-management  2020-01-01 00:00:00
# 4   5096624          USA         manure-management  2020-01-01 00:00:00
# 5   5096625          USA         manure-management  2020-01-01 00:00:00
# 6   5096625          USA         manure-management  2020-01-01 00:00:00
# 7   5096625          USA         manure-management  2020-01-01 00:00:00
# 8   5096625          USA         manure-management  2020-01-01 00:00:00
# 9   5096625          USA         manure-management  2020-01-01 00:00:00
#
#               end_time temporal_granularity         gas  emissions_quantity  \
# 0  2020-12-31 00:00:00               annual         co2            0.000000
# 1  2020-12-31 00:00:00               annual         ch4            3.308000
# 2  2020-12-31 00:00:00               annual         n2o           16.375634
# 3  2020-12-31 00:00:00               annual  co2e_100yr         4415.791310
# 4  2020-12-31 00:00:00               annual   co2e_20yr         4617.414944
# 5  2020-12-31 00:00:00               annual         co2            0.000000
# 6  2020-12-31 00:00:00               annual         ch4            3.308000
# 7  2020-12-31 00:00:00               annual         n2o           16.573646
# 8  2020-12-31 00:00:00               annual  co2e_100yr         4468.066610
# 9  2020-12-31 00:00:00               annual   co2e_20yr         4669.888256
#
#    emissions_factor      emissions_factor_units  capacity  \
# 0          0.000000  tonnes_gas_per_animal_head  0.001023
# 1          0.002000  tonnes_gas_per_animal_head  0.001023
# 2          0.009901  tonnes_gas_per_animal_head  0.001023
# 3          0.009901  tonnes_gas_per_animal_head  0.001023
# 4          0.009901  tonnes_gas_per_animal_head  0.001023
# 5          0.000000  tonnes_gas_per_animal_head  0.001053
# 6          0.002000  tonnes_gas_per_animal_head  0.001053
# 7          0.009901  tonnes_gas_per_animal_head  0.001053
# 8          0.009901  tonnes_gas_per_animal_head  0.001053
# 9          0.009901  tonnes_gas_per_animal_head  0.001053
#
#                      capacity_units  activity           activity_units  \
# 0  area_sq_meters_of_intensive_farm      1654  total_animal_head_count
# 1  area_sq_meters_of_intensive_farm      1654  total_animal_head_count
# 2  area_sq_meters_of_intensive_farm      1654  total_animal_head_count
# 3  area_sq_meters_of_intensive_farm      1654  total_animal_head_count
# 4  area_sq_meters_of_intensive_farm      1654  total_animal_head_count
# 5  area_sq_meters_of_intensive_farm      1674  total_animal_head_count
# 6  area_sq_meters_of_intensive_farm      1674  total_animal_head_count
# 7  area_sq_meters_of_intensive_farm      1674  total_animal_head_count
# 8  area_sq_meters_of_intensive_farm      1674  total_animal_head_count
# 9  area_sq_meters_of_intensive_farm      1674  total_animal_head_count
#
#                  created_date               modified_date       asset_name  \
# 0  2022-09-13 19:15:27.534582  2022-10-14 21:11:31.952288  USA_CA_beef_100
# 1  2022-09-13 19:15:27.534582  2022-10-14 21:11:31.952288  USA_CA_beef_100
# 2  2022-09-13 19:15:27.534582  2022-10-14 21:11:31.952288  USA_CA_beef_100
# 3  2022-09-13 19:15:27.534582  2022-10-14 21:11:31.952288  USA_CA_beef_100
# 4  2022-09-13 19:15:27.534582  2022-10-14 21:11:31.952288  USA_CA_beef_100
# 5  2022-09-13 19:15:27.534636  2022-10-14 21:11:31.952288  USA_CA_beef_101
# 6  2022-09-13 19:15:27.534636  2022-10-14 21:11:31.952288  USA_CA_beef_101
# 7  2022-09-13 19:15:27.534636  2022-10-14 21:11:31.952288  USA_CA_beef_101
# 8  2022-09-13 19:15:27.534636  2022-10-14 21:11:31.952288  USA_CA_beef_101
# 9  2022-09-13 19:15:27.534636  2022-10-14 21:11:31.952288  USA_CA_beef_101
#
#                asset_type                         st_astext
# 0  manure_management_beef  POINT(-121.14280701 37.69197101)
# 1  manure_management_beef  POINT(-121.14280701 37.69197101)
# 2  manure_management_beef  POINT(-121.14280701 37.69197101)
# 3  manure_management_beef  POINT(-121.14280701 37.69197101)
# 4  manure_management_beef  POINT(-121.14280701 37.69197101)
# 5  manure_management_beef   POINT(-121.2361908 38.21606455)
# 6  manure_management_beef   POINT(-121.2361908 38.21606455)
# 7  manure_management_beef   POINT(-121.2361908 38.21606455)
# 8  manure_management_beef   POINT(-121.2361908 38.21606455)
# 9  manure_management_beef   POINT(-121.2361908 38.21606455)

# %%
# Display the bottom [insert number here] rows to have a glimpse of how the dataframe looks like
# The number passed to the `df.tail()` is the number of rows that will be returned
df.tail(10)
# Out:
#        asset_id iso3_country original_inventory_sector           start_time  \
# 15235   5097539          USA         manure-management  2021-01-01 00:00:00
# 15236   5097539          USA         manure-management  2021-01-01 00:00:00
# 15237   5097539          USA         manure-management  2021-01-01 00:00:00
# 15238   5097539          USA         manure-management  2021-01-01 00:00:00
# 15239   5097916          USA         manure-management  2021-01-01 00:00:00
# 15240   5097916          USA         manure-management  2021-01-01 00:00:00
# 15241   5097916          USA         manure-management  2021-01-01 00:00:00
# 15242   5098097          USA         manure-management  2021-01-01 00:00:00
# 15243   5098097          USA         manure-management  2021-01-01 00:00:00
# 15244   5098097          USA         manure-management  2021-01-01 00:00:00
#
#                   end_time temporal_granularity         gas  \
# 15235  2021-12-31 00:00:00               annual         ch4
# 15236  2021-12-31 00:00:00               annual         n2o
# 15237  2021-12-31 00:00:00               annual  co2e_100yr
# 15238  2021-12-31 00:00:00               annual   co2e_20yr
# 15239  2021-12-31 00:00:00               annual         co2
# 15240  2021-12-31 00:00:00               annual         ch4
# 15241  2021-12-31 00:00:00               annual         n2o
# 15242  2021-12-31 00:00:00               annual         n2o
# 15243  2021-12-31 00:00:00               annual  co2e_100yr
# 15244  2021-12-31 00:00:00               annual   co2e_20yr
#
#        emissions_quantity  emissions_factor      emissions_factor_units  \
# 15235          209.568000          0.074000  tonnes_gas_per_animal_head
# 15236           43.776348          0.015458  tonnes_gas_per_animal_head
# 15237        17424.859870          0.015458  tonnes_gas_per_animal_head
# 15238        29204.444220          0.015458  tonnes_gas_per_animal_head
# 15239            0.000000          0.000000  tonnes_gas_per_animal_head
# 15240           39.050000          0.071000  tonnes_gas_per_animal_head
# 15241            8.501762          0.015458  tonnes_gas_per_animal_head
# 15242           12.087960          0.015458  tonnes_gas_per_animal_head
# 15243         4745.837572          0.015458  tonnes_gas_per_animal_head
# 15244         7867.157533          0.015458  tonnes_gas_per_animal_head
#
#        capacity                    capacity_units  activity  \
# 15235  1.000000  area_sq_meters_of_intensive_farm      2832
# 15236  1.000000  area_sq_meters_of_intensive_farm      2832
# 15237  1.000000  area_sq_meters_of_intensive_farm      2832
# 15238  1.000000  area_sq_meters_of_intensive_farm      2832
# 15239  0.004598  area_sq_meters_of_intensive_farm       550
# 15240  0.004598  area_sq_meters_of_intensive_farm       550
# 15241  0.004598  area_sq_meters_of_intensive_farm       550
# 15242  1.000000  area_sq_meters_of_intensive_farm       782
# 15243  1.000000  area_sq_meters_of_intensive_farm       782
# 15244  1.000000  area_sq_meters_of_intensive_farm       782
#
#                 activity_units                created_date  \
# 15235  total_animal_head_count  2022-09-13 19:15:27.562119
# 15236  total_animal_head_count  2022-09-13 19:15:27.562119
# 15237  total_animal_head_count  2022-09-13 19:15:27.562119
# 15238  total_animal_head_count  2022-09-13 19:15:27.562119
# 15239  total_animal_head_count  2022-09-13 19:15:27.565828
# 15240  total_animal_head_count  2022-09-13 19:15:27.565828
# 15241  total_animal_head_count  2022-09-13 19:15:27.565828
# 15242  total_animal_head_count  2022-09-13 19:15:27.567547
# 15243  total_animal_head_count  2022-09-13 19:15:27.567547
# 15244  total_animal_head_count  2022-09-13 19:15:27.567547
#
#                     modified_date         asset_name               asset_type  \
# 15235  2022-10-14 21:11:31.952288  USA_CA_dairy_1152  manure_management_dairy
# 15236  2022-10-14 21:11:31.952288  USA_CA_dairy_1152  manure_management_dairy
# 15237  2022-10-14 21:11:31.952288  USA_CA_dairy_1152  manure_management_dairy
# 15238  2022-10-14 21:11:31.952288  USA_CA_dairy_1152  manure_management_dairy
# 15239  2022-10-14 21:11:34.848764   USA_CA_dairy_323  manure_management_dairy
# 15240  2022-10-14 21:11:34.848764   USA_CA_dairy_323  manure_management_dairy
# 15241  2022-10-14 21:11:34.848764   USA_CA_dairy_323  manure_management_dairy
# 15242  2022-10-14 21:11:34.848764   USA_CA_dairy_487  manure_management_dairy
# 15243  2022-10-14 21:11:34.848764   USA_CA_dairy_487  manure_management_dairy
# 15244  2022-10-14 21:11:34.848764   USA_CA_dairy_487  manure_management_dairy
#
#                               st_astext
# 15235        POINT(-119.22059 36.02058)
# 15236        POINT(-119.22059 36.02058)
# 15237        POINT(-119.22059 36.02058)
# 15238        POINT(-119.22059 36.02058)
# 15239  POINT(-119.36182022 36.30475046)
# 15240  POINT(-119.36182022 36.30475046)
# 15241  POINT(-119.36182022 36.30475046)
# 15242   POINT(-121.0878937 37.56678924)
# 15243   POINT(-121.0878937 37.56678924)
# 15244   POINT(-121.0878937 37.56678924)
