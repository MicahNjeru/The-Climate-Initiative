# %% [markdown]
# <div align="center"> <h1>Country Cropland-Fires Emissions CSV</h1></div>

# %% [markdown]
# ### About This Notebook
# This notebook explores the contents of the csv file.
# Various exploratory techniques will be used to analyze the content of the csv and perform any necessary cleanups.

# %%
# Import necessary libraries to use for the exploration & analysis
import csv 
import pandas as pd
import matplotlib.pyplot as plt

# Set up the number of columns to use when showing a data frame using pandas
pd.set_option('display.max_columns', 200)

# %%
# Import the csv file and convert it to a pandas data frame 
df = pd.read_csv("../data/agriculture/country_cropland-fires_emissions.csv")

# %%
# Show the shape of the data frame (rows, columns)
# The returned value is the number of rows and columns in the dataframe
df.shape
# Out:
# (8785, 10)

# %%
# Show the first 5 rows by using the head command
df.head()
# Out:
#   iso3_country           start_time             end_time  \
# 0          GUF  2021-01-01 00:00:00  2021-12-31 00:00:00
# 1          AFG  2015-01-01 00:00:00  2015-12-31 00:00:00
# 2          AGO  2021-01-01 00:00:00  2021-12-31 00:00:00
# 3          AGO  2021-01-01 00:00:00  2021-12-31 00:00:00
# 4          AGO  2021-01-01 00:00:00  2021-12-31 00:00:00
#
#   original_inventory_sector  gas  emissions_quantity emissions_quantity_units  \
# 0            cropland-fires  co2        0.000000e+00                   tonnes
# 1            cropland-fires  co2        2.587182e+04                   tonnes
# 2            cropland-fires  co2        3.695608e+06                   tonnes
# 3            cropland-fires  ch4        1.885972e+04                   tonnes
# 4            cropland-fires  n2o        2.245205e+02                   tonnes
#
#   temporal_granularity                created_date               modified_date
# 0               annual  2022-08-09 15:18:51.401595                         NaN
# 1               annual  2022-08-09 15:18:51.338749  2022-10-11 06:39:21.192964
# 2               annual  2022-08-09 15:18:51.339924  2022-10-11 06:39:21.192964
# 3               annual  2022-08-09 15:18:51.339929  2022-10-11 06:39:21.192964
# 4               annual  2022-08-09 15:18:51.339933  2022-10-11 06:39:21.192964

# %%
# List out the columns 
columns = df.columns

index = 0 
print("Column Index\t Column Name")
for column in columns:
    print(f"{index}\t\t {column}")
    index += 1
# Out:
# Column Index	 Column Name
# 0		 iso3_country
# 1		 start_time
# 2		 end_time
# 3		 original_inventory_sector
# 4		 gas
# 5		 emissions_quantity
# 6		 emissions_quantity_units
# 7		 temporal_granularity
# 8		 created_date
# 9		 modified_date

# %%
# Check the data type of the column's content
df.dtypes
# Out:
# iso3_country                  object
# start_time                    object
# end_time                      object
# original_inventory_sector     object
# gas                           object
# emissions_quantity           float64
# emissions_quantity_units      object
# temporal_granularity          object
# created_date                  object
# modified_date                 object
# dtype: object

# %% [markdown]
# #### Here are some of the keys for understanding pandas data types
#
# object => String
#
# float64 => Float

# %%
# Check on the overal distribution of all numerical data columns
df.describe()
# Out:
#        emissions_quantity
# count        8.785000e+03
# mean         6.733472e+05
# std          2.682089e+06
# min          0.000000e+00
# 25%          0.000000e+00
# 50%          1.570820e+02
# 75%          5.472715e+04
# max          4.095321e+07

# %%
# Check on the summarized technical information of the pandas dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8785 entries, 0 to 8784
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   iso3_country               8785 non-null   object
#  1   start_time                 8785 non-null   object
#  2   end_time                   8785 non-null   object
#  3   original_inventory_sector  8785 non-null   object
#  4   gas                        8785 non-null   object
#  5   emissions_quantity         8785 non-null   float64
#  6   emissions_quantity_units   8785 non-null   object
#  7   temporal_granularity       8785 non-null   object
#  8   created_date               8785 non-null   object
#  9   modified_date              5862 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 686.5+ KB

# %%
# Display the top [insert number here] rows to have a glimpse of how the dataframe looks like
# The number passed to the `df.head()` is the number of rows that will be returned
df.head(10)
# Out:
#   iso3_country           start_time             end_time  \
# 0          GUF  2021-01-01 00:00:00  2021-12-31 00:00:00
# 1          AFG  2015-01-01 00:00:00  2015-12-31 00:00:00
# 2          AGO  2021-01-01 00:00:00  2021-12-31 00:00:00
# 3          AGO  2021-01-01 00:00:00  2021-12-31 00:00:00
# 4          AGO  2021-01-01 00:00:00  2021-12-31 00:00:00
# 5          AGO  2021-01-01 00:00:00  2021-12-31 00:00:00
# 6          AGO  2021-01-01 00:00:00  2021-12-31 00:00:00
# 7          AGO  2020-01-01 00:00:00  2020-12-31 00:00:00
# 8          AGO  2020-01-01 00:00:00  2020-12-31 00:00:00
# 9          AGO  2020-01-01 00:00:00  2020-12-31 00:00:00
#
#   original_inventory_sector         gas  emissions_quantity  \
# 0            cropland-fires         co2        0.000000e+00
# 1            cropland-fires         co2        2.587182e+04
# 2            cropland-fires         co2        3.695608e+06
# 3            cropland-fires         ch4        1.885972e+04
# 4            cropland-fires         n2o        2.245205e+02
# 5            cropland-fires  co2e_100yr        4.283088e+06
# 6            cropland-fires   co2e_20yr        5.288311e+06
# 7            cropland-fires         n2o        3.933690e+02
# 8            cropland-fires  co2e_100yr        7.504142e+06
# 9            cropland-fires   co2e_20yr        9.265334e+06
#
#   emissions_quantity_units temporal_granularity                created_date  \
# 0                   tonnes               annual  2022-08-09 15:18:51.401595
# 1                   tonnes               annual  2022-08-09 15:18:51.338749
# 2                   tonnes               annual  2022-08-09 15:18:51.339924
# 3                   tonnes               annual  2022-08-09 15:18:51.339929
# 4                   tonnes               annual  2022-08-09 15:18:51.339933
# 5                   tonnes               annual  2022-08-09 15:18:51.339941
# 6                   tonnes               annual  2022-08-09 15:18:51.339945
# 7                   tonnes               annual  2022-08-09 15:18:51.339847
# 8                   tonnes               annual  2022-08-09 15:18:51.339851
# 9                   tonnes               annual  2022-08-09 15:18:51.339856
#
#                 modified_date
# 0                         NaN
# 1  2022-10-11 06:39:21.192964
# 2  2022-10-11 06:39:21.192964
# 3  2022-10-11 06:39:21.192964
# 4  2022-10-11 06:39:21.192964
# 5  2022-10-11 06:39:21.192964
# 6  2022-10-11 06:39:21.192964
# 7  2022-10-11 06:39:21.192964
# 8  2022-10-11 06:39:21.192964
# 9  2022-10-11 06:39:21.192964

# %%
# Display the bottom [insert number here] rows to have a glimpse of how the dataframe looks like
# The number passed to the `df.tail()` is the number of rows that will be returned
df.tail(10)
# Out:
#      iso3_country           start_time             end_time  \
# 8775          WSM  2020-01-01 00:00:00  2020-12-31 00:00:00
# 8776          WSM  2020-01-01 00:00:00  2020-12-31 00:00:00
# 8777          WSM  2021-01-01 00:00:00  2021-12-31 00:00:00
# 8778          WSM  2021-01-01 00:00:00  2021-12-31 00:00:00
# 8779          WSM  2021-01-01 00:00:00  2021-12-31 00:00:00
# 8780          WSM  2021-01-01 00:00:00  2021-12-31 00:00:00
# 8781          WSM  2021-01-01 00:00:00  2021-12-31 00:00:00
# 8782          YEM  2019-01-01 00:00:00  2019-12-31 00:00:00
# 8783          YEM  2019-01-01 00:00:00  2019-12-31 00:00:00
# 8784          YEM  2019-01-01 00:00:00  2019-12-31 00:00:00
#
#      original_inventory_sector         gas  emissions_quantity  \
# 8775            cropland-fires  co2e_100yr            0.000000
# 8776            cropland-fires   co2e_20yr            0.000000
# 8777            cropland-fires         co2            0.000000
# 8778            cropland-fires         ch4            0.000000
# 8779            cropland-fires         n2o            0.000000
# 8780            cropland-fires  co2e_100yr            0.000000
# 8781            cropland-fires   co2e_20yr            0.000000
# 8782            cropland-fires         n2o            0.306198
# 8783            cropland-fires  co2e_100yr         5841.216053
# 8784            cropland-fires   co2e_20yr         7212.125571
#
#      emissions_quantity_units temporal_granularity  \
# 8775                   tonnes               annual
# 8776                   tonnes               annual
# 8777                   tonnes               annual
# 8778                   tonnes               annual
# 8779                   tonnes               annual
# 8780                   tonnes               annual
# 8781                   tonnes               annual
# 8782                   tonnes               annual
# 8783                   tonnes               annual
# 8784                   tonnes               annual
#
#                     created_date               modified_date
# 8775  2022-08-09 15:18:51.502111                         NaN
# 8776  2022-08-09 15:18:51.502116                         NaN
# 8777  2022-08-09 15:18:51.502186                         NaN
# 8778  2022-08-09 15:18:51.502192                         NaN
# 8779  2022-08-09 15:18:51.502197                         NaN
# 8780  2022-08-09 15:18:51.502204                         NaN
# 8781   2022-08-09 15:18:51.50221                         NaN
# 8782    2022-08-09 15:18:51.5033  2022-10-11 06:39:21.192964
# 8783  2022-08-09 15:18:51.503305  2022-10-11 06:39:21.192964
# 8784   2022-08-09 15:18:51.50331  2022-10-11 06:39:21.192964
