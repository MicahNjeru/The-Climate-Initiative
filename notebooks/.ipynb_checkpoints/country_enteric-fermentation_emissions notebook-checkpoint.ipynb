# %% [markdown]
# <div align="center"> <h1>Country Enteric-Fermentation Emissions CSV</h1></div>

# %% [markdown]
# ### About This Notebook
# This notebook explores the contents of the csv file.
# Various exploratory techniques will be used to analyze the content of the csv and perform any necessary cleanups.

# %%
# Import necessary libraries to use for the exploration & analysis
import csv 
import pandas as pd
import matplotlib.pyplot as plt

# Set up the number of columns to use when showing a data frame using pandas
pd.set_option('display.max_columns', 200)

# %%
# Import the csv file and convert it to a pandas data frame 
df = pd.read_csv("../data/agriculture/country_enteric-fermentation_emissions.csv")

# %%
# Show the shape of the data frame (rows, columns)
# The returned value is the number of rows and columns in the dataframe
df.shape
# Out:
# (8785, 10)

# %%
# Show the first 5 rows by using the head command
df.head()
# Out:
#   iso3_country           start_time             end_time  \
# 0          URY  2017-01-01 00:00:00  2017-12-31 00:00:00
# 1          MLI  2020-01-01 00:00:00  2020-12-31 00:00:00
# 2          MLI  2020-01-01 00:00:00  2020-12-31 00:00:00
# 3          MLT  2020-01-01 00:00:00  2020-12-31 00:00:00
# 4          MLT  2020-01-01 00:00:00  2020-12-31 00:00:00
#
#   original_inventory_sector  gas  emissions_quantity emissions_quantity_units  \
# 0      enteric-fermentation  co2                 0.0                   tonnes
# 1      enteric-fermentation  co2                 0.0                   tonnes
# 2      enteric-fermentation  n2o                 0.0                   tonnes
# 3      enteric-fermentation  co2                 0.0                   tonnes
# 4      enteric-fermentation  n2o                 0.0                   tonnes
#
#    temporal_granularity               created_date modified_date
# 0                   NaN  2022-09-06 12:39:52.76017           NaN
# 1                   NaN  2022-09-06 12:39:52.76017           NaN
# 2                   NaN  2022-09-06 12:39:52.76017           NaN
# 3                   NaN  2022-09-06 12:39:52.76017           NaN
# 4                   NaN  2022-09-06 12:39:52.76017           NaN

# %%
# List out the columns 
columns = df.columns

index = 0 
print("Column Index\t Column Name")
for column in columns:
    print(f"{index}\t\t {column}")
    index += 1
# Out:
# Column Index	 Column Name
# 0		 iso3_country
# 1		 start_time
# 2		 end_time
# 3		 original_inventory_sector
# 4		 gas
# 5		 emissions_quantity
# 6		 emissions_quantity_units
# 7		 temporal_granularity
# 8		 created_date
# 9		 modified_date

# %%
# Check the data type of the column's content
df.dtypes
# Out:
# iso3_country                  object
# start_time                    object
# end_time                      object
# original_inventory_sector     object
# gas                           object
# emissions_quantity           float64
# emissions_quantity_units      object
# temporal_granularity         float64
# created_date                  object
# modified_date                 object
# dtype: object

# %% [markdown]
# #### Here are some of the keys for understanding pandas data types
#
# object => String
#
# float64 => Float

# %%
# Check on the overal distribution of all numerical data columns
df.describe()
# Out:
#        emissions_quantity  temporal_granularity
# count        8.750000e+03                   0.0
# mean         9.019076e+06                   NaN
# std          5.630263e+07                   NaN
# min          0.000000e+00                   NaN
# 25%          0.000000e+00                   NaN
# 50%          0.000000e+00                   NaN
# 75%          7.411069e+05                   NaN
# max          1.180507e+09                   NaN

# %%
# Check on the summarized technical information of the pandas dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8785 entries, 0 to 8784
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   iso3_country               8785 non-null   object
#  1   start_time                 8785 non-null   object
#  2   end_time                   8785 non-null   object
#  3   original_inventory_sector  8785 non-null   object
#  4   gas                        8785 non-null   object
#  5   emissions_quantity         8750 non-null   float64
#  6   emissions_quantity_units   8785 non-null   object
#  7   temporal_granularity       0 non-null      float64
#  8   created_date               8785 non-null   object
#  9   modified_date              1200 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 686.5+ KB

# %%
# Drop all columns with null values
# Assign the dataframe with the dropped column to a new variable to save changes.
df = df.drop(["temporal_granularity"], axis=1)

# %%
# Confirm columns or Series (as they are called in pandas) are dropped
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8785 entries, 0 to 8784
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   iso3_country               8785 non-null   object
#  1   start_time                 8785 non-null   object
#  2   end_time                   8785 non-null   object
#  3   original_inventory_sector  8785 non-null   object
#  4   gas                        8785 non-null   object
#  5   emissions_quantity         8750 non-null   float64
#  6   emissions_quantity_units   8785 non-null   object
#  7   created_date               8785 non-null   object
#  8   modified_date              1200 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 617.8+ KB

# %%
# Display the top [insert number here] rows to have a glimpse of how the dataframe looks like
# The number passed to the `df.head()` is the number of rows that will be returned
df.head(10)
# Out:
#   iso3_country           start_time             end_time  \
# 0          URY  2017-01-01 00:00:00  2017-12-31 00:00:00
# 1          MLI  2020-01-01 00:00:00  2020-12-31 00:00:00
# 2          MLI  2020-01-01 00:00:00  2020-12-31 00:00:00
# 3          MLT  2020-01-01 00:00:00  2020-12-31 00:00:00
# 4          MLT  2020-01-01 00:00:00  2020-12-31 00:00:00
# 5          MLT  2020-01-01 00:00:00  2020-12-31 00:00:00
# 6          MLT  2020-01-01 00:00:00  2020-12-31 00:00:00
# 7          MMR  2020-01-01 00:00:00  2020-12-31 00:00:00
# 8          MMR  2020-01-01 00:00:00  2020-12-31 00:00:00
# 9          MNE  2020-01-01 00:00:00  2020-12-31 00:00:00
#
#   original_inventory_sector        gas  emissions_quantity  \
# 0      enteric-fermentation        co2                 0.0
# 1      enteric-fermentation        co2                 0.0
# 2      enteric-fermentation        n2o                 0.0
# 3      enteric-fermentation        co2                 0.0
# 4      enteric-fermentation        n2o                 0.0
# 5      enteric-fermentation        ch4              1351.7
# 6      enteric-fermentation  co2e_20yr            113542.8
# 7      enteric-fermentation        co2                 0.0
# 8      enteric-fermentation        n2o                 0.0
# 9      enteric-fermentation        co2                 0.0
#
#   emissions_quantity_units               created_date  \
# 0                   tonnes  2022-09-06 12:39:52.76017
# 1                   tonnes  2022-09-06 12:39:52.76017
# 2                   tonnes  2022-09-06 12:39:52.76017
# 3                   tonnes  2022-09-06 12:39:52.76017
# 4                   tonnes  2022-09-06 12:39:52.76017
# 5                   tonnes  2022-09-06 12:39:52.76017
# 6                   tonnes  2022-09-06 12:39:52.76017
# 7                   tonnes  2022-09-06 12:39:52.76017
# 8                   tonnes  2022-09-06 12:39:52.76017
# 9                   tonnes  2022-09-06 12:39:52.76017
#
#                 modified_date
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5  2022-09-14 20:50:03.260966
# 6  2022-09-14 20:50:03.260966
# 7                         NaN
# 8                         NaN
# 9                         NaN

# %%
# Display the bottom [insert number here] rows to have a glimpse of how the dataframe looks like
# The number passed to the `df.tail()` is the number of rows that will be returned
df.tail(10)
# Out:
#      iso3_country           start_time             end_time  \
# 8775          MHL  2021-01-01 00:00:00  2021-12-31 00:00:00
# 8776          MHL  2021-01-01 00:00:00  2021-12-31 00:00:00
# 8777          MHL  2021-01-01 00:00:00  2021-12-31 00:00:00
# 8778          MHL  2021-01-01 00:00:00  2021-12-31 00:00:00
# 8779          MHL  2021-01-01 00:00:00  2021-12-31 00:00:00
# 8780          MKD  2021-01-01 00:00:00  2021-12-31 00:00:00
# 8781          MKD  2021-01-01 00:00:00  2021-12-31 00:00:00
# 8782          MKD  2021-01-01 00:00:00  2021-12-31 00:00:00
# 8783          MKD  2021-01-01 00:00:00  2021-12-31 00:00:00
# 8784          MKD  2021-01-01 00:00:00  2021-12-31 00:00:00
#
#      original_inventory_sector         gas  emissions_quantity  \
# 8775      enteric-fermentation         co2                 0.0
# 8776      enteric-fermentation         n2o                 0.0
# 8777      enteric-fermentation         ch4                 0.0
# 8778      enteric-fermentation   co2e_20yr                 0.0
# 8779      enteric-fermentation  co2e_100yr                 0.0
# 8780      enteric-fermentation         co2                 0.0
# 8781      enteric-fermentation         n2o                 0.0
# 8782      enteric-fermentation         ch4             25550.5
# 8783      enteric-fermentation   co2e_20yr           2146242.0
# 8784      enteric-fermentation  co2e_100yr            715414.0
#
#      emissions_quantity_units               created_date  \
# 8775                   tonnes  2022-09-07 09:56:37.90632
# 8776                   tonnes  2022-09-07 09:56:37.90632
# 8777                   tonnes  2022-09-07 09:56:37.90632
# 8778                   tonnes  2022-09-07 09:56:37.90632
# 8779                   tonnes  2022-09-07 09:56:37.90632
# 8780                   tonnes  2022-09-07 09:56:37.90632
# 8781                   tonnes  2022-09-07 09:56:37.90632
# 8782                   tonnes  2022-09-07 09:56:37.90632
# 8783                   tonnes  2022-09-07 09:56:37.90632
# 8784                   tonnes  2022-09-07 09:56:37.90632
#
#                    modified_date
# 8775                         NaN
# 8776                         NaN
# 8777                         NaN
# 8778                         NaN
# 8779                         NaN
# 8780                         NaN
# 8781                         NaN
# 8782  2022-09-14 20:49:54.253962
# 8783  2022-09-14 20:49:54.253962
# 8784  2022-09-14 20:49:54.253962
