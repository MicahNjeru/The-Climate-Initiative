# %% [markdown]
# <div align="center"> <h1>Country Rice-Cultivation Emissions CSV</h1></div>

# %% [markdown]
# ### About This Notebook
# This notebook explores the contents of the csv file.
# Various exploratory techniques will be used to analyze the content of the csv and perform any necessary cleanups.

# %%
# Import necessary libraries to use for the exploration & analysis
import csv 
import pandas as pd
import matplotlib.pyplot as plt

# Set up the number of columns to use when showing a data frame using pandas
pd.set_option('display.max_columns', 200)

# %%
# Import the csv file and convert it to a pandas data frame 
df = pd.read_csv("../data/agriculture/country_rice-cultivation_emissions.csv")

# %%
# Show the shape of the data frame (rows, columns)
# The returned value is the number of rows and columns in the dataframe
df.shape
# Out:
# (8785, 10)

# %%
# Show the first 5 rows by using the head command
df.head()
# Out:
#   iso3_country           start_time             end_time  \
# 0          NGA  2015-01-01 00:00:00  2015-12-31 00:00:00
# 1          NGA  2015-01-01 00:00:00  2015-12-31 00:00:00
# 2          NGA  2015-01-01 00:00:00  2015-12-31 00:00:00
# 3          NGA  2015-01-01 00:00:00  2015-12-31 00:00:00
# 4          NGA  2015-01-01 00:00:00  2015-12-31 00:00:00
#
#   original_inventory_sector         gas  emissions_quantity  \
# 0          rice-cultivation         co2        0.000000e+00
# 1          rice-cultivation         ch4        9.114961e+05
# 2          rice-cultivation         n2o        0.000000e+00
# 3          rice-cultivation  co2e_100yr        2.479269e+07
# 4          rice-cultivation   co2e_20yr        7.364889e+07
#
#   emissions_quantity_units temporal_granularity                created_date  \
# 0                   tonnes               annual  2022-08-09 14:12:03.915538
# 1                   tonnes               annual  2022-08-09 14:12:03.915607
# 2                   tonnes               annual  2022-08-09 14:12:03.915629
# 3                   tonnes               annual  2022-08-09 14:12:03.915652
# 4                   tonnes               annual  2022-08-09 14:12:03.915714
#
#   modified_date
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
# List out the columns 
columns = df.columns

index = 0 
print("Column Index\t Column Name")
for column in columns:
    print(f"{index}\t\t {column}")
    index += 1
# Out:
# Column Index	 Column Name
# 0		 iso3_country
# 1		 start_time
# 2		 end_time
# 3		 original_inventory_sector
# 4		 gas
# 5		 emissions_quantity
# 6		 emissions_quantity_units
# 7		 temporal_granularity
# 8		 created_date
# 9		 modified_date

# %%
# Check the data type of the column's content
df.dtypes
# Out:
# iso3_country                  object
# start_time                    object
# end_time                      object
# original_inventory_sector     object
# gas                           object
# emissions_quantity           float64
# emissions_quantity_units      object
# temporal_granularity          object
# created_date                  object
# modified_date                 object
# dtype: object

# %% [markdown]
# #### Here are some of the keys for understanding pandas data types
#
# object => String
#
# float64 => Float

# %%
# Check on the overal distribution of all numerical data columns
df.describe()
# Out:
#        emissions_quantity
# count        8.750000e+03
# mean         2.898446e+06
# std          3.068922e+07
# min          0.000000e+00
# 25%          0.000000e+00
# 50%          0.000000e+00
# 75%          7.571225e+02
# max          9.719791e+08

# %%
# Check on the summarized technical information of the pandas dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8785 entries, 0 to 8784
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   iso3_country               8785 non-null   object
#  1   start_time                 8785 non-null   object
#  2   end_time                   8785 non-null   object
#  3   original_inventory_sector  8785 non-null   object
#  4   gas                        8785 non-null   object
#  5   emissions_quantity         8750 non-null   float64
#  6   emissions_quantity_units   8785 non-null   object
#  7   temporal_granularity       8785 non-null   object
#  8   created_date               8785 non-null   object
#  9   modified_date              4474 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 686.5+ KB

# %%
# Display the top [insert number here] rows to have a glimpse of how the dataframe looks like
# The number passed to the `df.head()` is the number of rows that will be returned
df.head(10)
# Out:
#   iso3_country           start_time             end_time  \
# 0          NGA  2015-01-01 00:00:00  2015-12-31 00:00:00
# 1          NGA  2015-01-01 00:00:00  2015-12-31 00:00:00
# 2          NGA  2015-01-01 00:00:00  2015-12-31 00:00:00
# 3          NGA  2015-01-01 00:00:00  2015-12-31 00:00:00
# 4          NGA  2015-01-01 00:00:00  2015-12-31 00:00:00
# 5          NGA  2016-01-01 00:00:00  2016-12-31 00:00:00
# 6          NGA  2016-01-01 00:00:00  2016-12-31 00:00:00
# 7          NGA  2016-01-01 00:00:00  2016-12-31 00:00:00
# 8          NGA  2016-01-01 00:00:00  2016-12-31 00:00:00
# 9          NGA  2016-01-01 00:00:00  2016-12-31 00:00:00
#
#   original_inventory_sector         gas  emissions_quantity  \
# 0          rice-cultivation         co2        0.000000e+00
